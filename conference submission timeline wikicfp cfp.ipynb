# %% [markdown]
# # Crawler of Call for Papers (source: http://www.wikicfp.com)

# %% [markdown]
# ## Example on how to retrieve the call for paper deadlines of 'TMA 2019'

# %%
url="http://www.wikicfp.com/cfp/servlet/tool.search?q=TMA+2019&year=2019"

# %% [markdown]
# ## Libraries

# %%
import cfscrape
from lxml import etree
import pandas as pd
import urllib
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Function for retrieving the CFP information

# %%
def retrieve_cfp_info (conference,year):
    ###Parsing the name of the conference
    conference_url = urllib.parse.quote_plus(conference)

    ### Composing the URL
    url = "http://www.wikicfp.com/cfp/servlet/tool.search?q="+conference_url+"&year="+str(year)

    ### Instanciating the Scraper
    scraper = cfscrape.create_scraper()
    
    ### Scraping a URL
    scraped_html=scraper.get(url).content
    
    try:
        ### Get tables in the HTML
        tables = pd.read_html(scraped_html)

        ### Reading the dataframe
        df=pd.DataFrame({'conference': tables[1][0],'location':tables[1][1],'deadline':tables[1][2]})

        ### Drop the first lines till line 'event'
        df.drop(df.index[:df.loc[df['conference'] == 'Event'].index[0]+1],inplace=True) 

        ### Merge odds and even rows
        df = pd.concat([df.iloc[0::2].reset_index(drop=True), df.iloc[1::2].reset_index(drop=True)],  sort=True, axis=1)
        df['requested']=conference+" "+str(year)

        ### Changing the name of the columns
        df.columns = ['retrieved', 'name', 'blank','conference_date','location','hard_deadline','requested']

        ### Drop the blank column
        df.drop(columns=['blank'], inplace=True)
          
        try:
            df['hard_deadline'] = df['hard_deadline'][0].split(' (')[0]
        except:
            next

        df['hard_deadline'] = pd.to_datetime(df['hard_deadline'], format='%b %d, %Y',errors='coerce')

        return df.iloc[0]
    
    except:
        return pd.DataFrame({'retrieved': np.NaN, 'name':np.NaN, 'conference_date':np.NaN,'location':np.NaN,'hard_deadline':np.NaN,'requested':[conference+" "+str(year)] })

# %% [markdown]
# ## Example:

# %%
retrieve_cfp_info('NOMS',2018)
# Out:
# retrieved          NOMS 2018
# name               Network Operations and Management Symposium
# conference_date    Apr 23, 2018 - Apr 27, 2018
# location           Taipei, Taiwan, China
# hard_deadline      2017-09-05 00:00:00
# requested          NOMS 2018
# Name: 0, dtype: object

# %% [markdown]
# ## Retrieving for a list of conferences

# %%
top_conferences = ['SIGCOMM',
                   'USENIX ATC']

# %%
year = 2019
measurement_conferences = ['PAM',
                           'TMA',
                           'IMC']

print('Measurement Conferences:')
result=pd.DataFrame()
for conference in measurement_conferences:
    result = result.append(retrieve_cfp_info(conference,year), ignore_index=True, sort=True)

result[['requested', 'retrieved', 'hard_deadline','name', 'conference_date','location']].sort_values(by=['hard_deadline']).reset_index(drop=True)
# Out:
# Measurement Conferences:
#   requested               retrieved hard_deadline  \
# 0  PAM 2019  PAM 2019               2018-10-17
# 1  TMA 2019  TMA 2019               2019-02-15
# 2  IMC 2019  IMC Art & Science 2019 2019-02-15
#
#                                                                name  \
# 0  Passive and Active Network Measurement
# 1  Network Traffic Measurement and Analysis Conference
# 2  Innovative Methodologies: International Art & Science Conference
#
#                conference_date                               location
# 0  Mar 27, 2019 - Mar 29, 2019  Puerto Varas, Chile
# 1  Jun 19, 2019 - Jun 21, 2019  Paris, France
# 2  Apr 9, 2019 - Apr 11, 2019   University of Zagreb, Zagreb, Croatia

# %%
security_conferences = ['IEEE S&P',
                        'USENIX SECURITY', 
                        'ACM AsiaCCS', 
                        'ESORICS',
                        'CSF',
                        'ACISP',
                        'SOUPS',
                        'ACM CCS',
                        'DSN',
                        'IFIPSEC',
                        'DFRWS',
                        'DIMVA',
                        'CSFW',
                        'ISC',
                        'ICICS',
                        'RAID',
                        'CNS',
                        'NSPW',
#                         'USENIX WOOT',
                        'ACSAC',
                        'SecureComm',
                        'MALWARE',
                        'EURO S&P',
                        'NDSS',
                        'ICISC',
                        'CODASPY',
                        'SAC']

print('Security Conferences:')
result=pd.DataFrame()
for conference in security_conferences:
    result = result.append(retrieve_cfp_info(conference,year), ignore_index=True, sort=True)


result[['requested', 'retrieved', 'hard_deadline','name', 'conference_date','location']].sort_values(by=['hard_deadline']).reset_index(drop=True)
# Out:
# Security Conferences:
#                requested         retrieved hard_deadline  \
# 0   NDSS 2019             NDSS 2019        2018-08-07
# 1   CODASPY 2019          CODASPY 2019     2018-09-24
# 2   USENIX SECURITY 2019  FAST 2019        2018-09-26
# 3   IEEE S&P 2019         IEEE S&P 2019    2018-12-01
# 4   EURO S&P 2019         IEEE S&P 2019    2018-12-01
# 5   DSN 2019              DSN 2019         2018-12-07
# 6   ISC 2019              ISC HPC 2019     2019-01-07
# 7   ACM AsiaCCS 2019      ACM ASIACCS 2019 2019-01-15
# 8   DFRWS 2019            DFRWS 2019       2019-02-03
# 9   ACM CCS 2019          CCS 2019         2019-02-05
# 10  ICICS 2019            ICICS 2019       2019-02-10
# 11  ACISP 2019            ACISP 2019       2019-02-15
# 12  DIMVA 2019            DIMVA 2019       2019-02-18
# 13  MALWARE 2019          DIMVA 2019       2019-02-18
# 14  CSF 2019              CSF 2019         2019-02-26
# 15  SOUPS 2019            SOUPS 2019       2019-02-28
# 16  IFIPSEC 2019          IFIPSEC 2019     2019-03-01
# 17  ESORICS 2019          ESORICS 2019     2019-04-22
# 18  CNS 2019              BrainMosaic 2019 2019-08-29
# 19  SAC 2019              KLP@SAC 2019     2019-09-10
# 20  CSFW 2019             NaN              NaT
# 21  RAID 2019             NaN              NaT
# 22  NSPW 2019             NaN              NaT
# 23  ACSAC 2019            NaN              NaT
# 24  SecureComm 2019       NaN              NaT
# 25  ICISC 2019            ICISC 2019       NaT
#
#                                                                                                     name  \
# 0   Network and Distributed System Security Symposium
# 1   ACM Conference on Data and Application Security and Privacy
# 2   17th USENIX Conference on File and Storage Technologies
# 3   IEEE Symposium on Security and Privacy
# 4   IEEE Symposium on Security and Privacy
# 5   Dependable Systems and Networks
# 6   ISC High Performance 2019
# 7   The 14th ACM ASIA Conference on Computer and Communications Security
# 8   Digital Forensic Research Workshop
# 9   26th ACM Conference on Computer and Communications Security
# 10  The 10th International Conference on Information and Communication Systems
# 11  The 24th Australasian Conference on Information Security and Privacy
# 12  16th International Conference on Detection of Intrusions and Malware & Vulnerability Assessment
# 13  16th International Conference on Detection of Intrusions and Malware & Vulnerability Assessment
# 14  32nd IEEE Computer Security Foundations Symposium
# 15  Fifteenth Symposium on Usable Privacy and Security
# 16  IFIP Information Security Conference & Privacy Conference - IFIP Technical Commitee 11
# 17  The 24th European Symposium on Research in Computer Security
# 18  The Brain Mosaic: Cellular heterogeneity in the CNS (2nd edition)
# 19  Knowledge and Language Processing Track @ The 34th ACM Symposium on Applied Computing - ACM SAC 2019
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  3rd International Conference on Inventive Systems and Control
#
#                 conference_date                            location
# 0   Feb 24, 2019 - Feb 27, 2019  San Diego, CA
# 1   Mar 25, 2019 - Mar 27, 2019  Dallas, TX, USA
# 2   Feb 25, 2019 - Feb 28, 2019  Boston, MA, USA
# 3   May 20, 2019 - May 22, 2019  San Francisco, CA
# 4   May 20, 2019 - May 22, 2019  San Francisco, CA
# 5   Jun 24, 2019 - Jun 27, 2019  Portland, Oregon, USA
# 6   Jun 16, 2019 - Jun 20, 2019  Frankfurt, Germany
# 7   Jul 7, 2019 - Jul 12, 2019   Auckland, New Zeland
# 8   Jul 14, 2019 - Jul 17, 2019  Portland, OR
# 9   Nov 11, 2019 - Nov 15, 2019  London
# 10  Jun 11, 2019 - Jun 13, 2019  Jordan
# 11  Jul 3, 2019 - Jul 5, 2019    Christchurch, New Zealnad
# 12  Jun 19, 2019 - Jun 20, 2019  Gothenburg, Sweden
# 13  Jun 19, 2019 - Jun 20, 2019  Gothenburg, Sweden
# 14  Jun 25, 2019 - Jun 28, 2019  Hoboken, NJ, USA
# 15  Aug 11, 2019 - Aug 13, 2019  Santa Clara, CA, USA
# 16  Jun 25, 2019 - Jun 27, 2019  Lisbon, Portual
# 17  Sep 23, 2019 - Sep 27, 2019  Luxembourg
# 18  Sep 30, 2019 - Oct 11, 2019  Ku Leuven, Naamsestraat 22, Leuven
# 19  Apr 8, 2019 - Apr 12, 2019   Limassol, Cyprus
# 20  NaN                          NaN
# 21  NaN                          NaN
# 22  NaN                          NaN
# 23  NaN                          NaN
# 24  NaN                          NaN
# 25  Jan 10, 2019 - Jan 11, 2019  Coimbatore, Tamil Nadu, India

# %% [markdown]
# ## Management Conferences

# %%
year=2019
management_conferences = ['IFIP/IEEE IM',
                          'NOMS',
                          'CNSM',
                          'NETWORKING']

result=pd.DataFrame()
for conference in management_conferences:
    result = result.append(retrieve_cfp_info(conference,year), ignore_index=True, sort=True)

    
result = result[['requested', 'retrieved', 'hard_deadline','name', 'conference_date','location']].sort_values(by=['hard_deadline']).reset_index(drop=True)
result
# Out:
#            requested                       retrieved hard_deadline  \
# 0  IFIP/IEEE IM 2019  IFIP/IEEE IM 2019              2018-09-10
# 1  NETWORKING 2019    IEEE--ICCT--Ei and Scopus 2019 2019-05-01
# 2  NOMS 2019          NaN                            NaT
# 3  CNSM 2019          NaN                            NaT
#
#                                                                                                        name  \
# 0  IFIP/IEEE International Symposium on Integrated Network Management (IM 2019)
# 1  2019 19th IEEE International Conference on Communication Technology (ICCT 2019)--Ei Compendex and Scopus
# 2  NaN
# 3  NaN
#
#                conference_date            location
# 0  Apr 8, 2019 - Apr 12, 2019   Washington DC, USA
# 1  Oct 16, 2019 - Oct 19, 2019  Xi'an, China
# 2  NaN                          NaN
# 3  NaN                          NaN

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(9,2))
ax = plt.subplot(111)
ax.axis('off')
ax.table(cellText=df.values, colLabels=df.columns, bbox=[0,0,1,1])
